# %% [markdown]
# <a href="https://colab.research.google.com/github/yoalbiel-nyoap/omnicampus_data_science/blob/main/OmniCampus_Data_Science_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print("Numpy version:", np.__version__)
print("pandas version:", pd.__version__)
print("ALL Data Science libraries are working!")
# Out:
# Numpy version: 2.1.3
# pandas version: 2.2.3
# ALL Data Science libraries are working!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
